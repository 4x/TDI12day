# %%
import numpy as np
from bokeh.plotting import figure, show

# %%
from bokeh.io import output_notebook

# %%
N=4000

# %%
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5

# %%
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
# Out:
# GlyphRenderer(id='1037', ...)

# %%
show(p)
# Out:
#   <div class="bk-root" id="51e4cbd4-8330-4aae-bed1-8619f0b27a5c" data-root-id="1003"></div>

# %%
TOOLS=["hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select,poly_select,lasso_select"]
colors2 = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]
p1=figure(width=300, height=300, tools=TOOLS)
p1.scatter(x, y, radius=radii, fill_color=colors2, fill_alpha=0.6, line_color=None)

colors2 = ["#%02x%02x%02x" % (150, int(g), int(b)) for g,b in zip(50+2*x, 30+2*y)]
p2=figure(width=300, height=300, tools=TOOLS)
p2.scatter(x, y, radius=radii, fill_color=colors2, fill_alpha=0.6, line_color=None)
# Out:
# GlyphRenderer(id='1491', ...)

# %%
show(p1)
show(p2)
# Out:
#   <div class="bk-root" id="f2295a0c-c6d5-486d-8f30-a2446ff271e0" data-root-id="1395"></div>
#   <div class="bk-root" id="a2cb54bc-612d-403a-8921-a03926c2e6c6" data-root-id="1444"></div>

# %%
from bokeh.plotting import figure, output_file, show
output_file("circles.html")
p = figure(plot_width=400, plot_height=400)
p.circle([1, 2, 3, 4, 5], [6, 7, 7, 4, 5], size = 18, color="navy", alpha=0.15)
show(p)
# Out:
#   <div class="bk-root" id="0703fc56-df59-4183-bc5c-28c48b269ae1" data-root-id="1727"></div>

# %%
output_file("squares.html")
p = figure(plot_width=400, plot_height=400)
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p.square(x, y, size=20, color="olive", alpha=.8)
show(p)
# Out:
#   <div class="bk-root" id="d0cc07e8-fc58-4eb2-b088-6e0a2adf44ae" data-root-id="2035"></div>
